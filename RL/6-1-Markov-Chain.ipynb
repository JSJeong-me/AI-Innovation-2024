# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/AI-Innovation-2024/blob/main/RL/6-1-Markov-Chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random as rm

# %%
# The statespace
states = ["Sleep","Icecream","Run"]

# Possible sequences of events
transitionName = [["SS","SR","SI"],["RS","RR","RI"],["IS","IR","II"]]

# Probabilities matrix (transition matrix)
transitionMatrix = [[0.2,0.6,0.2],[0.1,0.6,0.3],[0.2,0.7,0.1]]

# %%
if sum(transitionMatrix[0])+sum(transitionMatrix[1])+sum(transitionMatrix[1]) != 3:
    print("Somewhere, something went wrong. Transition matrix, perhaps?")
else: print("All is gonna be okay, you should move on!! ;)")
# Out:
# All is gonna be okay, you should move on!! ;)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# A function that implements the Markov model to forecast the state/mood.
def activity_forecast(days):
    # Choose the starting state
    activityToday = "Sleep"
    print("Start state: " + activityToday)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    activityList = [activityToday]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    while i != days:
        if activityToday == "Sleep":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "SS":
                prob = prob * 0.2
                activityList.append("Sleep")
                pass
            elif change == "SR":
                prob = prob * 0.6
                activityToday = "Run"
                activityList.append("Run")
            else:
                prob = prob * 0.2
                activityToday = "Icecream"
                activityList.append("Icecream")
        elif activityToday == "Run":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "RR":
                prob = prob * 0.5
                activityList.append("Run")
                pass
            elif change == "RS":
                prob = prob * 0.2
                activityToday = "Sleep"
                activityList.append("Sleep")
            else:
                prob = prob * 0.3
                activityToday = "Icecream"
                activityList.append("Icecream")
        elif activityToday == "Icecream":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "II":
                prob = prob * 0.1
                activityList.append("Icecream")
                pass
            elif change == "IS":
                prob = prob * 0.2
                activityToday = "Sleep"
                activityList.append("Sleep")
            else:
                prob = prob * 0.7
                activityToday = "Run"
                activityList.append("Run")
        i += 1
    print("Possible states: " + str(activityList))
    print("End state after "+ str(days) + " days: " + activityToday)
    print("Probability of the possible sequence of states: " + str(prob))

# Function that forecasts the possible state for the next 2 days
activity_forecast(2)
# Out:
# Start state: Sleep
# Possible states: ['Sleep', 'Sleep', 'Run']
# End state after 2 days: Run
# Probability of the possible sequence of states: 0.12

# %%
def activity_forecast(days):
    # Choose the starting state
    activityToday = "Sleep"
    activityList = [activityToday]
    i = 0
    prob = 1
    while i != days:
        if activityToday == "Sleep":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "SS":
                prob = prob * 0.2
                activityList.append("Sleep")
                pass
            elif change == "SR":
                prob = prob * 0.6
                activityToday = "Run"
                activityList.append("Run")
            else:
                prob = prob * 0.2
                activityToday = "Icecream"
                activityList.append("Icecream")
        elif activityToday == "Run":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "RR":
                prob = prob * 0.5
                activityList.append("Run")
                pass
            elif change == "RS":
                prob = prob * 0.2
                activityToday = "Sleep"
                activityList.append("Sleep")
            else:
                prob = prob * 0.3
                activityToday = "Icecream"
                activityList.append("Icecream")
        elif activityToday == "Icecream":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "II":
                prob = prob * 0.1
                activityList.append("Icecream")
                pass
            elif change == "IS":
                prob = prob * 0.2
                activityToday = "Sleep"
                activityList.append("Sleep")
            else:
                prob = prob * 0.7
                activityToday = "Run"
                activityList.append("Run")
        i += 1
    return activityList

# To save every activityList
list_activity = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_activity.append(activity_forecast(2))

# Check out all the `activityList` we collected
print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Run'
for smaller_list in list_activity:
    if(smaller_list[2] == "Run"):
        count += 1

# Calculate the probability of starting from state:'Sleep' and ending at state:'Run'
percentage = (count/10000) * 100
print("The probability of starting at state:'Sleep' and ending at state:'Run'= " + str(percentage) + "%")
# Out:
# [['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Icecream'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Icecream'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Icecream', 'Sleep'], ['Sleep', 'Sleep', 'Icecream'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Sleep'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Run', 'Icecream'], ['Sleep', 'Sleep', 'Run'], ['Sleep', 'Sleep', 'Icecream'], ['Sleep', 'Run', 'Sleep'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Run', 'Run'], ['Sleep', 'Icecream',  ...
# The probability of starting at state:'Sleep' and ending at state:'Run'= 14.030000000000001%
