# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/AI-Innovation-2024/blob/main/OpenCV/3-10-Web-Custom_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.10.12 torch-2.4.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.6/225.8 GB disk)

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data ../data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights /content/best.pt --img 640 --conf 0.4 --source /content/naver.jpg
# Out:
# detect: weights=['/content/best.pt'], source=/content/naver.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-368-gb163ff8d Python-3.10.12 torch-2.4.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/naver.jpg: 352x640 35 buttons, 1 field, 1 heading, 8 images, 1 link, 43 texts, 258.6ms
# Speed: 2.8ms pre-process, 258.6ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
display.Image(filename='/content/yolov5/runs/detect/exp2/naver.jpg', width=600)
