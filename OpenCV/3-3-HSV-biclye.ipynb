# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/AI-Innovation-2024/blob/main/OpenCV/3-3-HSV-biclye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '4.10.0'

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=18Ha-BokHfKVlbpxyAtDTdSFOdTDFgyii' -O bicycle.png

# %%
src = cv2.imread('./bicycle.png', cv2.IMREAD_UNCHANGED)

# %%
src.shape
# Out:
# (1534, 2045, 4)

# %%
cv2_imshow(src)

# %%
src_rgb = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

# %%
src_rgb = cv2.resize(src_rgb, (0,0), fx=0.3, fy=0.3)

# %%
cv2_imshow(src_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=614x460>

# %%
# cv2_imshow(src)

# %% [markdown]
# high_yellow[255, 213, 58]
# low_yellow[221, 195, 5]

# %%
import numpy as np

# %%
low_yellow = np.array([221, 195, 5])
high_yellow = np.array([255, 213, 58])

# %%
mask = cv2.inRange(src_rgb, low_yellow, high_yellow)

# %%
import cv2 # make sure to import the cv2 module
result_src = cv2.bitwise_and(src_rgb, src_rgb, mask = mask) # src was not defined, I am assuming you meant src_rgb

# %%
# result_src = cv2.bitwise_and(src, src, mask = mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGB size=614x460>

# %%
low_yellow = np.array([40, 0, 0])
high_yellow = np.array([255, 255, 255])

# %%
src_rgb = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

# %%
src_hsv = cv2.cvtColor(src_rgb, cv2.COLOR_RGB2HSV)

# %%
mask = cv2.inRange(src_hsv, low_yellow, high_yellow)

# %%
result_src = cv2.bitwise_and(src, src, mask = mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534>
