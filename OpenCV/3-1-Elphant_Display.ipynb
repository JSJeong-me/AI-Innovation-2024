# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/AI-Innovation-2024/blob/main/OpenCV/3-1-Elphant_Display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# Load the image
image_path = './elephant2.png' # 'elephant2.png'
image = cv2.imread(image_path)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (532, 946, 3)

# %%
# seg01 = image[10:160, 10:200]

# %%
elephant1 = image[171:318,75:206]
elephant2 = image[71:523,259:868]

# %%
# Display the image using cv2_imshow
# cv2_imshow(image)
# cv2_imshow(seg01)
# cv2_imshow(elephant1)
cv2_imshow(elephant2)
# Out:
# <PIL.Image.Image image mode=RGB size=609x452>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x252>
