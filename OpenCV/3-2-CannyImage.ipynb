# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/AI-Innovation-2024/blob/main/OpenCV/3-2-CannyImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1T-IRqZ4hhn2i2tywkhgs8uewjUORL0oa' -O beach.jpeg

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load the image using cv2.imread
image = cv2.imread("beach.jpeg")

# Now display the image
cv2_imshow(image)

# %%
import cv2
from PIL import Image
import numpy as np

low_threshold = 75
high_threshold = 200

np_image = np.array(image)

canny_image = cv2.Canny(np_image, low_threshold, high_threshold)

canny_image = canny_image[:, :, None]
canny_image = np.concatenate([canny_image, canny_image, canny_image], axis=2)
canny_image = Image.fromarray(canny_image)

canny_image
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1365>
